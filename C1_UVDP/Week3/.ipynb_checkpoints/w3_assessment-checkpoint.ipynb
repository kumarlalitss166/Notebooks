# %% [markdown]
# In this assignment we'll ask you to plot multiple variables.
#
# You will use what you find in this assignment to answer the questions in the quiz that follows. It may be useful to keep this notebook side-by-side with this week's quiz on your screen.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 100)

path = "Cartwheeldata.csv"

# %%
# First, you must import the cartwheel data from the path given above
df = pd.read_csv('Cartwheeldata.csv') # using pandas, read in the csv data found at the url defined by 'path'

# %%
# Next, look at the 'head' of our DataFrame 'df'. 
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %% [markdown]
# If you can't remember a function, open a previous notebook or video as a reference, or use your favorite search engine to look for a solution.

# %% [markdown]
# ## Scatter plots

# %% [markdown]
# First, let's looks at two variables that we expect to have a strong relationship, 'Height' and 'Wingspan'.

# %%
# Make a Seaborn scatter plot with x = height and y = wingspan using sns.scatterplot(x, y)
sns.lmplot(data=df,x='Height',y='Wingspan',hue='Gender',fit_reg=True)

# %%
sns.FacetGrid(df,col='Gender').map(plt.scatter,'Height','Wingspan').add_legend()

# %% [markdown]
# How would you describe the relationship between 'Height' and 'Wingspan'?
# Questions you can ask:
# * Is it linear?
# * Are there outliers?
# * Are their ranges similar or different?
#
# How else could you describe the relationship?

# %% [markdown]
# * The relationship is linear.
# * Yes, there are outliers in the data.
# * Their ranges are different.

# %%
#sns.boxplot(data=df,x='Height',y='Wingspan')

# %%
print(df.Height.dropna().describe())
print(df.Wingspan.dropna().describe())
# Out:
# count    25.000000
# mean     67.650000
# std       4.431187
# min      61.500000
# 25%      64.000000
# 50%      68.000000
# 75%      71.000000
# max      75.000000
# Name: Height, dtype: float64
# count    25.000000
# mean     66.260000
# std       5.492647
# min      57.500000
# 25%      62.000000
# 50%      66.000000
# 75%      71.000000
# max      76.000000
# Name: Wingspan, dtype: float64

# %% [markdown]
# Now let's look at two variables that we don't yet assume have a strong relationship, 'Wingspan' and 'CWDistance'

# %%
# Make a Seaborn scatter plot with x = wingspan and y = cartwheel distance
sns.regplot(data=df,x='Wingspan',y='CWDistance')
# Out:
# <AxesSubplot:xlabel='Wingspan', ylabel='CWDistance'>

# %% [markdown]
# How would you describe the relationship between 'Wingspan' and 'CWDistance'?
# * Is it linear?
# * Are there outliers?
# * Are their ranges similar or different?
#
# How else could you describe the relationship?

# %% [markdown]
# * Yes, the relationship is linear.
# * Yes , there are outliers in the data.
# * Their ranges are different.

# %%
print(df.Height.dropna().describe())
print(df.CWDistance.dropna().describe())
print(df.Wingspan.dropna().describe())
# Out:
# count    25.000000
# mean     67.650000
# std       4.431187
# min      61.500000
# 25%      64.000000
# 50%      68.000000
# 75%      71.000000
# max      75.000000
# Name: Height, dtype: float64
# count     25.000000
# mean      82.480000
# std       15.058552
# min       63.000000
# 25%       70.000000
# 50%       81.000000
# 75%       92.000000
# max      115.000000
# Name: CWDistance, dtype: float64
# count    25.000000
# mean     66.260000
# std       5.492647
# min      57.500000
# 25%      62.000000
# 50%      66.000000
# 75%      71.000000
# max      76.000000
# Name: Wingspan, dtype: float64

# %% [markdown]
# Let makes the same plot as above, but now include 'Gender' as the color scheme by including the argument
# ```
# hue=df['Gender']
# ```
# in the Seaborn function

# %%
# Make a Seaborn scatter plot with x = wingspan and y = cartwheel distance, and hue = gender
sns.scatterplot(data=df,x='Height',y='CWDistance',hue='Gender')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='CWDistance'>

# %% [markdown]
# Does this new information on the plot change your interpretation of the relationship between 'Wingspan' and 'CWDistance'?

# %% [markdown]
# Yes, now we can see that `Males` have more Height to CWDistance than
# the `Females`

# %% [markdown]
# ## Barcharts
# Now lets plot barplots of 'Glasses'

# %%
# Make a Seaborn barplot with x = glasses and y = cartwheel distance
sns.barplot(data=df,y='CWDistance',x='Glasses')
# Out:
# <AxesSubplot:xlabel='Glasses', ylabel='CWDistance'>

# %% [markdown]
# What can you say about the relationship of 'Glasses' and 'CWDistance'?

# %%
# Make the same Seaborn boxplot as above, but include gender for the hue argument
sns.barplot(data=df,y='CWDistance',x='Glasses',hue='Gender')
# Out:
# <AxesSubplot:xlabel='Glasses', ylabel='CWDistance'>

# %% [markdown]
# How does this new plot change your interpretation about the relationship of 'Glasses' and 'CWDistance'?

# %% [markdown]
# It shows that the `Males` wearing glasses have high CWDistance than `Females` whereas `Males` with no glasses have low CWDistance than `Females`.
